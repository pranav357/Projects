# %% [markdown]
# # <font color = "red">[READ THIS] Before you start</font>
# Welcome to UpLevel mini-projects! In this series, you're challenged to independently work (with our guidance) with data that you will collect to UpLevel yourself.
#
# We hope you're excited to embark on this adventure.
# ### Warning:
# This isn't just any coding course or programmes, where you receive helper code as you move from one code block to another.
#
# This is when things get <em>real</em>.
#
# In this project, you will receive instructions to execute a task along with an intended outcome. Most importantly, we will provide you with directions you can go to, to pick up code independently and implement it in this notebook.
#
# Don't worry though, we'll be dropping lots of resources you can consult and these readings will contain everything you need to succeed. You can also perform independent research to find answers independently. You just have to read closely and pick out the parts that make most sense.
#
# <strong>We make you do this not because we're lazy bastards but because being able to indepedently find code is a highly underrated skill and that's something all companies look out for.</strong>
#
# If you're really stuck and are on the verge of giving up, we gotchu fam. Head on over to https://www.facebook.com/UpLevelSG/ and post your questions there.
#
# ### What we'll be doing:
# In this project, we will do the following:
#
# 1. Download hospital ICU data (Part I)
# 2. Perform data cleaning (Part I)
# 3. Exploratory data analysis (Part II)
# 4. Engineer new features (Part III)
# 5. Apply machine learning techniques to train a model to predict ICU survival status (Part IV)
#
# ### Expectations:
# We're not going to sugarcoat it - it'll be challenging at times. You have to promise to put in the time and effort to UpLevel yourself.
#
# But we promise you that it'll ultimately be fun and rewarding, and you'll come out of it stronger and more confident than before.

# %% [markdown]
# # Introduction
#
# You are presented with a dataset where you have to predict ICU survival of patients admitted into different hospitals.
#
# We'll first approach this problem from a layperson's perspective.
#
# In this notebook, you will do the following:
# 1. Import libraries
# 2. Get your ICU data
# 3. Visualize the missing data
# 4. Clean the dataset
# 4. Export your cleaned data as a CSV file
#
# ### Step 1: Import the following libraries
# - pandas

# %%
# Step 1: import your library

# %% [markdown]
# ### Step 2: Download the data and data dictionary
# Next, retrieve your data and save it into the same project folder! Make sure you download both files.
#
# Click here for the <a href = "https://uplevelsg.s3-ap-southeast-1.amazonaws.com/ProjectICUSurvival/data.csv">data</a> (61.7 MB)
#
# Click here for the <a href = "https://uplevelsg.s3-ap-southeast-1.amazonaws.com/ProjectICUSurvival/data_dictionary.csv">data dictionary</a> (29.2 kB)

# %% [markdown]
# ### Step 3: Read the data and data dictionary using Excel
# Sounds like a weird instruction, but sometimes it's good to take a cursory look at your CSV using Excel.
#
# Excel's well equipped to handle tabular data, and you'll need to develop some kind of intuition around your data.
#
# Also, oftentimes your data will come with a data dictionary, be it when you're working in a company or in a hackathon.
#
# There are over 180 columns in the dataset, so it's useful to get acquianted with them. We won't be using most of it for now, but it'll come in handy in Part V.

# %% [markdown]
# ### Step 4: Load your downloaded CSV into a DataFrame
# Now that you're done with the data dictionary (I hope you did read it), it's time to read the data and load it into a DataFrame.
#
# Read your CSV and save assign it to a variable of your choosing.

# %%
# Step 4: Read your CSV

# %% [markdown]
# ### Step 5: Count the number of missing values in each column
# Let's assess the missing values in each column. You'll be able to do it with one line of code.
#
# You should see something like this:
#
# ![IsnullSumExhibitA.png](attachment:IsnullSumExhibitA.png)
#
# <strong>Hint: Google "count missing values in column pandas"</strong>

# %%
# Step 5: count the number of NAs in each column

# %% [markdown]
# ### Step 6: Drop rows containing NA
# Oh man, there's just too many to look at. How troublesome. Why not just drop everything that's NA then.
#
# Let's take a quick look at what happens if you drop rows with missing data.
#
# Do a <strong>drop NA</strong> (don't overwrite your original variable), and look at the resulting DataFrame.
#
# <strong>Hint: Google "drop na rows pandas"</strong>

# %%
# Step 6: Just drop any rows that contain a single NA

# %% [markdown]
# ### Step 7: Try other ways of assessing the missing data
# Wait a minute. Only 25 rows after removing NA from the rows? That's madness.
#
# Seems like we're too aggressive. Looks like we'll have to take a step back and look at the number of missing rows properly. We'll need to look into this in depth.
#
# There are a few ways to do it:
# 1. Turning the object from Step 5 into a DataFrame and printing them out one by one for inspection
# 2. Using a visual method to visualize
# 3. Turning the object from Step 5 into a DataFrame, then into a CSV for manual inspection
#
# ![IsNullSumWays.png](attachment:IsNullSumWays.png)
#
# <strong>Hint 1: For Approaches 1, Google for "iterate through each row pandas"</strong>
#
# <strong>Hint 2: For Approaches 1 and 3, take what you did from Step 5 and reset the index - you'll be surprised</strong>
#
# <strong>Hint 3: For Approach 2, Google for "visualize missing data python"</strong>

# %%
# Step 7 (Approach 1): Get a DataFrame of the sum of nulls, then print them line by line
# Step 7a: Declare a variable and save the sum of isnulls inside

# Step 7b: Reset the index()

# Step 7c: Iterate through the rows and print out both the column containing the name of columns and the missing total

# %%
# Step 7 (Approach 2): Visualize the missing values

# %%
# Step 7 (Approach 3): Get a DataFrame of the sum of nulls, then export as CSV
# Step 7a: Declare a variable and save the sum of isnulls inside

# Step 7b: Reset the index()

# Step 7c: Export the DataFrame as CSV and inspect the CSV manually

# %% [markdown]
# ### Step 8: Keep columns that to not have many missing values
# Whichever approaches you did, you will realize that there are many columns with missing values.
#
# This explains why you losts so many rows when you did the dropna method.
#
# Instead, we will focus on dropping NAs on a <strong>subset</strong> of rows. We're choosing these rows because they seem important in an ICU setting, from a common sense point of view.
#
# We will focus on dropping NAs only in:
# 1. age
# 2. bmi
# 3. ethnicity
# 4. gender
# 5. height
# 6. icu_admit_source
# 7. weight
# 8. aids
# 9. cirrhosis
# 10. diabetes_mellitus
# 11. hepatic_failure
# 12. immunosuppression
# 13. leukemia
# 14. lymphoma
# 15. solid_tumor_with_metastasis
#
# That's a lot, but we'll start with this (more on this in Part V).
#
# <strong>Hint: Google "pandas drop na rows based on column"</strong>

# %%
# Step 8: Drop NAs only based on the 15 columns mentioned above

# %% [markdown]
# ### Step 9: Export your semi-cleaned dataset into CSV
# Sanity check: Make sure your DataFrame has 82,965 rows with 186 columns before exporting. If you're wondering whether a loss of 10,000+ rows is ok, it's ok for now since we did not lose too much data (~11% only).
#
# If you have difficulty reaching this part where you have this specific number of rows, please ping us on our Facebook group at https://www.facebook.com/UpLevelSG/ and post your questions there.
#
# If you're all good, export your DataFrame as a CSV and we'll proceed to Part II.

# %%
# Step 9: Export your DataFrame as a CSV
