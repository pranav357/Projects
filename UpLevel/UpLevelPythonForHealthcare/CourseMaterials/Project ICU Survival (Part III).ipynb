# %% [markdown]
# # Introduction
# In Part II, we performed visualization to develop an intuition behind our data.
#
# In this Part, we will engineer additional features (columns) for our modelling. What is feature engineering? Feature engineering is the process of turning existing features into new columns.
#
# Though feature engineering, machine learning models' performances sometimes improve. As such, it's always a good idea to extract new information.
#
# Recommended readings:
# 1. https://towardsdatascience.com/feature-engineering-for-machine-learning-3a5e293a5114
# 2. https://machinelearningmastery.com/discover-feature-engineering-how-to-engineer-features-and-how-to-get-good-at-it/
#
# In this notebook, you will do the following:
# 1. one-hot encode ethnicity
# 2. one-hot encode gender
# 3. one-hot encode icu_stay_type
# 4. one-hot encode icu_type
# 4. combine the DataFrames containing the one-hot encoded categorical values with the original DataFrame
# 5. export the large DataFrame as CSV
#
# We can do more, but this is a good start for now.
#
# <strong>Hint: Google "dummy variables python" to learn more about dummifying your categorical values in a column</strong>
#
# <strong>Hint 2: Search within pandas...</strong>
#
# ### Step 1: Import the following library
# - pandas as pd

# %%
# Step 1: import pandas

# %% [markdown]
# ### Step 2: Read semi-cleaned CSV from Part I as a DataFrame
# We will read the semi-cleaned CSV exported in Part I for our Part's purpose.

# %%
# Step 2: Read your Part I CSV as a DataFrame

# %% [markdown]
# For one-hot encoding/dummification of the categorical values, there are various ways to do it.
#
# However, no matter which method you do it, make sure you drop one column to avoid the <strong>dummy variable trap</strong>.
#
# For example, if your column contains four categorical values, you'd have to drop one of the four columns after one-hot encoding.
#
# ![OnehotEncodingExample.png](attachment:OnehotEncodingExample.png)
#
# In this example, we drop is_Purple because is_Purple is redundant, i.e. you can infer that row's values based on is_Black, is_Blue, and is_Red. If all of those values are 0, it means the row contains purple instead.
#
# Suggested reading: https://machinelearningmastery.com/one-hot-encoding-for-categorical-data/
#
# ### Step 3: Dummify "ethnicity"

# %%
# Step 3: Declare a variable and store the dummified/one-hot encoded values from 'ethnicity'

# %% [markdown]
# ### Step 4: Dummify 'gender'
# Don't forget to drop one column so you have only one column for dummified gender

# %%
# Step 4: Declare a variable and store the dummified/one-hot encoded values from 'gender'

# %% [markdown]
# ### Step 5: Dummify 'icu_stay'
# Let's get the dummified data for 'icu_stay' as well.

# %%
# Step 5: Declare a variable and store the dummified/one-hot encoded values from 'icu_stay'

# %% [markdown]
# ### Step 6: Dummify 'icu_type'

# %%
# Step 6: Declare a variable and store the dummified/one-hot encoded values from 'icu_type'

# %% [markdown]
# ### Step 7: Select columns for modelling dataset
# We'll pick only a few columns for now, and combine that subset DataFrame with the DataFrames containing the dummified categorical data for Part IV where we will be doing our modelling.
#
# We will pick the following columns:
# 1. hospital_death
# 2. age
# 3. bmi
# 4. elective_surgery
# 5. height
# 6. pre_icu_los_days
# 7. readmission_status
# 8. weight
#
# Don't worry about the rest of the 170+ columns, as we will revisit them in Part V. For now, declare a list containing the column names above, and create a new DataFrame containing these columns only.
#
# <strong>Hint: Google "selecting multiple columns pandas"</strong>

# %%
# Step 7: Pick the specified columns in the DataFrame

# %% [markdown]
# ### Step 8: Combine all DataFrames together
# Now that you've dummified the columns, it's time to combine the DataFrame from Step 7 with the DataFrames containing the dummified data.
#
# You'll have to <strong>concatenate</strong> them together.
#
# <strong>Hint: Google for "combine data frames side by side"</strong>

# %%
# Step 8: Concatenate your DataFrames together

# %% [markdown]
# Sanity check: you'll see something like this.
#
# ![CombinedDataFrame.png](attachment:CombinedDataFrame.png)
#
# Your DataFrame will have <strong>82,965 rows and 23 columns</strong>.
#
# ### Step 9: Export your combined DataFrame as CSV
# Now that you've combined your DataFrames, it's time to export it for machine learning in Part IV.

# %%
# Step 9: Export your DataFrame as a CSV
